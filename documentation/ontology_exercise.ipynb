# %% [markdown]
# # Ontology Exercise
#
# This is a notebook working through the ontology exercise I was assigned as part of a programming exercise. For more general information, please see the README at the base of this repository.
#
# Our first task will be to import the libraries we want to work with. Beyond the standard `pandas` import, we will also be using the `rdfpandas` library so we can convert our input Turtle (.ttl) file to a DataFrame. Also, we were asked to use SPARQL to get IDs and labels, so we will need to use the `rdflib` library. We'll be querying APIs so naturally we will be dealing with JSON data. Ultimately, this exercise will produce a CSV output file.

# %%
import rdflib
from rdfpandas.graph import to_dataframe
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import urllib
import json
import os

# %% [markdown]
# ## Step 1: Read in Ontology File
# First we'll navigate so that our working directory is where our input file is. Then we'll be able to read in the file.

# %%
os.getcwd()
# Out:
# '/home/zelgius/Github/ontology-exercise/documentation'

# %%
os.chdir('../input')

# %% [markdown]
# ## Step 2: Load into Data Structure
# Scanning [`rdfpandas` documentation](https://github.com/cadmiumkitty/rdfpandas) quickly, we see the syntax is very similar to that of `rdflib`, and we are merely using an extra step with the function `to_dataframe()`. Let's convert the provided turtle file to a DataFrame:

# %%
g = rdflib.Graph()
g.parse('programming_exercise.skos.ttl', format = 'ttl')
df = to_dataframe(g)

# %% [markdown]
# Let's have an overview of our DataFrame:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 437 entries, http://purl.obolibrary.org/obo/DOID_0040098 to https://localhost:8443/ontology/Applicanttest/APPLICANTTEST
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rdf:type{URIRef}               437 non-null    object
#  1   skos:altLabel{Literal}[0]@en   337 non-null    object
#  2   skos:altLabel{Literal}[1]@en   207 non-null    object
#  3   skos:altLabel{Literal}[2]@en   111 non-null    object
#  4   skos:altLabel{Literal}[3]@en   57 non-null     object
#  5   skos:altLabel{Literal}[4]@en   29 non-null     object
#  6   skos:altLabel{Literal}[5]@en   20 non-null     object
#  7   skos:altLabel{Literal}[6]@en   14 non-null     object
#  8   skos:altLabel{Literal}[7]@en   8 non-null      object
#  9   skos:altLabel{Literal}[8]@en   6 non-null      object
#  10  skos:altLabel{Literal}[9]@en   5 non-null      object
#  11  skos:altLabel{Literal}[10]@en  3 non-null      object
#  12  skos:altLabel{Literal}[11]@en  3 non-null      object
#  13  skos:broader{URIRef}[0]        435 non-null    object
#  14  skos:broader{URIRef}[1]        9 non-null      object
#  15  skos:definition{Literal}       238 non-null    object
#  16  skos:inScheme{URIRef}          436 non-null    object
#  17  skos:prefLabel{Literal}@en     437 non-null    object
#  18  dcterms:title{Literal}@en      1 non-null      object
#  19  skos:hasTopConcept{URIRef}     1 non-null      object
#  20  skos:topConceptOf{URIRef}      1 non-null      object
# dtypes: object(21)
# memory usage: 75.1+ KB

# %%
df[0:20]
# Out:
#                                             rdf:type{URIRef}  \
# http://purl.obolibrary.org/obo/DOID_0040098     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050072     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050096     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050116     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050135     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050169     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050185     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050251     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050260     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050278     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050279     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050426     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050428     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050429     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050448     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050467     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050468     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050486     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050487     skos:Concept
# http://purl.obolibrary.org/obo/DOID_0050508     skos:Concept
#
#                                                         skos:altLabel{Literal}[0]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050072                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050096                 dermatophytosis of beard
# http://purl.obolibrary.org/obo/DOID_0050116                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050135                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050169                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050185                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050251                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050260                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050278                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050279                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050426                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050428                      Thost-Unna Syndrome
# http://purl.obolibrary.org/obo/DOID_0050429                 BENIGN CHRONIC PEMPHIGUS
# http://purl.obolibrary.org/obo/DOID_0050448                       white sponge nevus
# http://purl.obolibrary.org/obo/DOID_0050467  Erythrokeratodermia Figurata Variabilis
# http://purl.obolibrary.org/obo/DOID_0050468                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050486                                     Rash
# http://purl.obolibrary.org/obo/DOID_0050487                                      NaN
# http://purl.obolibrary.org/obo/DOID_0050508                                      NaN
#
#                                              skos:altLabel{Literal}[1]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                           NaN
# http://purl.obolibrary.org/obo/DOID_0050072                           NaN
# http://purl.obolibrary.org/obo/DOID_0050096                           NaN
# http://purl.obolibrary.org/obo/DOID_0050116                           NaN
# http://purl.obolibrary.org/obo/DOID_0050135                           NaN
# http://purl.obolibrary.org/obo/DOID_0050169                           NaN
# http://purl.obolibrary.org/obo/DOID_0050185                           NaN
# http://purl.obolibrary.org/obo/DOID_0050251                           NaN
# http://purl.obolibrary.org/obo/DOID_0050260                           NaN
# http://purl.obolibrary.org/obo/DOID_0050278                           NaN
# http://purl.obolibrary.org/obo/DOID_0050279                           NaN
# http://purl.obolibrary.org/obo/DOID_0050426                           NaN
# http://purl.obolibrary.org/obo/DOID_0050428           Unna-Thost Syndrome
# http://purl.obolibrary.org/obo/DOID_0050429    Pemphigus, Benign Familial
# http://purl.obolibrary.org/obo/DOID_0050448  white sponge nevus of Cannon
# http://purl.obolibrary.org/obo/DOID_0050467              Greither Disease
# http://purl.obolibrary.org/obo/DOID_0050468                           NaN
# http://purl.obolibrary.org/obo/DOID_0050486                     exanthema
# http://purl.obolibrary.org/obo/DOID_0050487                           NaN
# http://purl.obolibrary.org/obo/DOID_0050508                           NaN
#
#                                                                   skos:altLabel{Literal}[2]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050072                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050096                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050116                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050135                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050169                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050185                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050251                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050260                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050278                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050279                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050426                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050428  diffuse nonepidermolytic palmomplantar keratod...
# http://purl.obolibrary.org/obo/DOID_0050429                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050448                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050467                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050468                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050486                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050487                                                NaN
# http://purl.obolibrary.org/obo/DOID_0050508                                                NaN
#
#                                             skos:altLabel{Literal}[3]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                          NaN
# http://purl.obolibrary.org/obo/DOID_0050072                          NaN
# http://purl.obolibrary.org/obo/DOID_0050096                          NaN
# http://purl.obolibrary.org/obo/DOID_0050116                          NaN
# http://purl.obolibrary.org/obo/DOID_0050135                          NaN
# http://purl.obolibrary.org/obo/DOID_0050169                          NaN
# http://purl.obolibrary.org/obo/DOID_0050185                          NaN
# http://purl.obolibrary.org/obo/DOID_0050251                          NaN
# http://purl.obolibrary.org/obo/DOID_0050260                          NaN
# http://purl.obolibrary.org/obo/DOID_0050278                          NaN
# http://purl.obolibrary.org/obo/DOID_0050279                          NaN
# http://purl.obolibrary.org/obo/DOID_0050426                          NaN
# http://purl.obolibrary.org/obo/DOID_0050428                      tylosis
# http://purl.obolibrary.org/obo/DOID_0050429                          NaN
# http://purl.obolibrary.org/obo/DOID_0050448                          NaN
# http://purl.obolibrary.org/obo/DOID_0050467                          NaN
# http://purl.obolibrary.org/obo/DOID_0050468                          NaN
# http://purl.obolibrary.org/obo/DOID_0050486                          NaN
# http://purl.obolibrary.org/obo/DOID_0050487                          NaN
# http://purl.obolibrary.org/obo/DOID_0050508                          NaN
#
#                                             skos:altLabel{Literal}[4]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                          NaN
# http://purl.obolibrary.org/obo/DOID_0050072                          NaN
# http://purl.obolibrary.org/obo/DOID_0050096                          NaN
# http://purl.obolibrary.org/obo/DOID_0050116                          NaN
# http://purl.obolibrary.org/obo/DOID_0050135                          NaN
# http://purl.obolibrary.org/obo/DOID_0050169                          NaN
# http://purl.obolibrary.org/obo/DOID_0050185                          NaN
# http://purl.obolibrary.org/obo/DOID_0050251                          NaN
# http://purl.obolibrary.org/obo/DOID_0050260                          NaN
# http://purl.obolibrary.org/obo/DOID_0050278                          NaN
# http://purl.obolibrary.org/obo/DOID_0050279                          NaN
# http://purl.obolibrary.org/obo/DOID_0050426                          NaN
# http://purl.obolibrary.org/obo/DOID_0050428                          NaN
# http://purl.obolibrary.org/obo/DOID_0050429                          NaN
# http://purl.obolibrary.org/obo/DOID_0050448                          NaN
# http://purl.obolibrary.org/obo/DOID_0050467                          NaN
# http://purl.obolibrary.org/obo/DOID_0050468                          NaN
# http://purl.obolibrary.org/obo/DOID_0050486                          NaN
# http://purl.obolibrary.org/obo/DOID_0050487                          NaN
# http://purl.obolibrary.org/obo/DOID_0050508                          NaN
#
#                                             skos:altLabel{Literal}[5]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                          NaN
# http://purl.obolibrary.org/obo/DOID_0050072                          NaN
# http://purl.obolibrary.org/obo/DOID_0050096                          NaN
# http://purl.obolibrary.org/obo/DOID_0050116                          NaN
# http://purl.obolibrary.org/obo/DOID_0050135                          NaN
# http://purl.obolibrary.org/obo/DOID_0050169                          NaN
# http://purl.obolibrary.org/obo/DOID_0050185                          NaN
# http://purl.obolibrary.org/obo/DOID_0050251                          NaN
# http://purl.obolibrary.org/obo/DOID_0050260                          NaN
# http://purl.obolibrary.org/obo/DOID_0050278                          NaN
# http://purl.obolibrary.org/obo/DOID_0050279                          NaN
# http://purl.obolibrary.org/obo/DOID_0050426                          NaN
# http://purl.obolibrary.org/obo/DOID_0050428                          NaN
# http://purl.obolibrary.org/obo/DOID_0050429                          NaN
# http://purl.obolibrary.org/obo/DOID_0050448                          NaN
# http://purl.obolibrary.org/obo/DOID_0050467                          NaN
# http://purl.obolibrary.org/obo/DOID_0050468                          NaN
# http://purl.obolibrary.org/obo/DOID_0050486                          NaN
# http://purl.obolibrary.org/obo/DOID_0050487                          NaN
# http://purl.obolibrary.org/obo/DOID_0050508                          NaN
#
#                                             skos:altLabel{Literal}[6]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                          NaN
# http://purl.obolibrary.org/obo/DOID_0050072                          NaN
# http://purl.obolibrary.org/obo/DOID_0050096                          NaN
# http://purl.obolibrary.org/obo/DOID_0050116                          NaN
# http://purl.obolibrary.org/obo/DOID_0050135                          NaN
# http://purl.obolibrary.org/obo/DOID_0050169                          NaN
# http://purl.obolibrary.org/obo/DOID_0050185                          NaN
# http://purl.obolibrary.org/obo/DOID_0050251                          NaN
# http://purl.obolibrary.org/obo/DOID_0050260                          NaN
# http://purl.obolibrary.org/obo/DOID_0050278                          NaN
# http://purl.obolibrary.org/obo/DOID_0050279                          NaN
# http://purl.obolibrary.org/obo/DOID_0050426                          NaN
# http://purl.obolibrary.org/obo/DOID_0050428                          NaN
# http://purl.obolibrary.org/obo/DOID_0050429                          NaN
# http://purl.obolibrary.org/obo/DOID_0050448                          NaN
# http://purl.obolibrary.org/obo/DOID_0050467                          NaN
# http://purl.obolibrary.org/obo/DOID_0050468                          NaN
# http://purl.obolibrary.org/obo/DOID_0050486                          NaN
# http://purl.obolibrary.org/obo/DOID_0050487                          NaN
# http://purl.obolibrary.org/obo/DOID_0050508                          NaN
#
#                                             skos:altLabel{Literal}[7]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                          NaN
# http://purl.obolibrary.org/obo/DOID_0050072                          NaN
# http://purl.obolibrary.org/obo/DOID_0050096                          NaN
# http://purl.obolibrary.org/obo/DOID_0050116                          NaN
# http://purl.obolibrary.org/obo/DOID_0050135                          NaN
# http://purl.obolibrary.org/obo/DOID_0050169                          NaN
# http://purl.obolibrary.org/obo/DOID_0050185                          NaN
# http://purl.obolibrary.org/obo/DOID_0050251                          NaN
# http://purl.obolibrary.org/obo/DOID_0050260                          NaN
# http://purl.obolibrary.org/obo/DOID_0050278                          NaN
# http://purl.obolibrary.org/obo/DOID_0050279                          NaN
# http://purl.obolibrary.org/obo/DOID_0050426                          NaN
# http://purl.obolibrary.org/obo/DOID_0050428                          NaN
# http://purl.obolibrary.org/obo/DOID_0050429                          NaN
# http://purl.obolibrary.org/obo/DOID_0050448                          NaN
# http://purl.obolibrary.org/obo/DOID_0050467                          NaN
# http://purl.obolibrary.org/obo/DOID_0050468                          NaN
# http://purl.obolibrary.org/obo/DOID_0050486                          NaN
# http://purl.obolibrary.org/obo/DOID_0050487                          NaN
# http://purl.obolibrary.org/obo/DOID_0050508                          NaN
#
#                                             skos:altLabel{Literal}[8]@en  ...  \
# http://purl.obolibrary.org/obo/DOID_0040098                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050072                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050096                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050116                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050135                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050169                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050185                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050251                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050260                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050278                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050279                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050426                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050428                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050429                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050448                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050467                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050468                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050486                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050487                          NaN  ...
# http://purl.obolibrary.org/obo/DOID_0050508                          NaN  ...
#
#                                             skos:altLabel{Literal}[10]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                           NaN
# http://purl.obolibrary.org/obo/DOID_0050072                           NaN
# http://purl.obolibrary.org/obo/DOID_0050096                           NaN
# http://purl.obolibrary.org/obo/DOID_0050116                           NaN
# http://purl.obolibrary.org/obo/DOID_0050135                           NaN
# http://purl.obolibrary.org/obo/DOID_0050169                           NaN
# http://purl.obolibrary.org/obo/DOID_0050185                           NaN
# http://purl.obolibrary.org/obo/DOID_0050251                           NaN
# http://purl.obolibrary.org/obo/DOID_0050260                           NaN
# http://purl.obolibrary.org/obo/DOID_0050278                           NaN
# http://purl.obolibrary.org/obo/DOID_0050279                           NaN
# http://purl.obolibrary.org/obo/DOID_0050426                           NaN
# http://purl.obolibrary.org/obo/DOID_0050428                           NaN
# http://purl.obolibrary.org/obo/DOID_0050429                           NaN
# http://purl.obolibrary.org/obo/DOID_0050448                           NaN
# http://purl.obolibrary.org/obo/DOID_0050467                           NaN
# http://purl.obolibrary.org/obo/DOID_0050468                           NaN
# http://purl.obolibrary.org/obo/DOID_0050486                           NaN
# http://purl.obolibrary.org/obo/DOID_0050487                           NaN
# http://purl.obolibrary.org/obo/DOID_0050508                           NaN
#
#                                             skos:altLabel{Literal}[11]@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                           NaN
# http://purl.obolibrary.org/obo/DOID_0050072                           NaN
# http://purl.obolibrary.org/obo/DOID_0050096                           NaN
# http://purl.obolibrary.org/obo/DOID_0050116                           NaN
# http://purl.obolibrary.org/obo/DOID_0050135                           NaN
# http://purl.obolibrary.org/obo/DOID_0050169                           NaN
# http://purl.obolibrary.org/obo/DOID_0050185                           NaN
# http://purl.obolibrary.org/obo/DOID_0050251                           NaN
# http://purl.obolibrary.org/obo/DOID_0050260                           NaN
# http://purl.obolibrary.org/obo/DOID_0050278                           NaN
# http://purl.obolibrary.org/obo/DOID_0050279                           NaN
# http://purl.obolibrary.org/obo/DOID_0050426                           NaN
# http://purl.obolibrary.org/obo/DOID_0050428                           NaN
# http://purl.obolibrary.org/obo/DOID_0050429                           NaN
# http://purl.obolibrary.org/obo/DOID_0050448                           NaN
# http://purl.obolibrary.org/obo/DOID_0050467                           NaN
# http://purl.obolibrary.org/obo/DOID_0050468                           NaN
# http://purl.obolibrary.org/obo/DOID_0050486                           NaN
# http://purl.obolibrary.org/obo/DOID_0050487                           NaN
# http://purl.obolibrary.org/obo/DOID_0050508                           NaN
#
#                                                                  skos:broader{URIRef}[0]  \
# http://purl.obolibrary.org/obo/DOID_0040098  http://purl.obolibrary.org/obo/DOID_0060039
# http://purl.obolibrary.org/obo/DOID_0050072       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050096       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050116    http://purl.obolibrary.org/obo/DOID_12179
# http://purl.obolibrary.org/obo/DOID_0050135       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050169       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050185       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050251       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050260       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050278  http://purl.obolibrary.org/obo/DOID_0050135
# http://purl.obolibrary.org/obo/DOID_0050279  http://purl.obolibrary.org/obo/DOID_0050135
# http://purl.obolibrary.org/obo/DOID_0050426       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050428     http://purl.obolibrary.org/obo/DOID_3390
# http://purl.obolibrary.org/obo/DOID_0050429     http://purl.obolibrary.org/obo/DOID_9182
# http://purl.obolibrary.org/obo/DOID_0050448       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050467       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050468       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050486       http://purl.obolibrary.org/obo/DOID_37
# http://purl.obolibrary.org/obo/DOID_0050487  http://purl.obolibrary.org/obo/DOID_0050486
# http://purl.obolibrary.org/obo/DOID_0050508     http://purl.obolibrary.org/obo/DOID_8736
#
#                                             skos:broader{URIRef}[1]  \
# http://purl.obolibrary.org/obo/DOID_0040098                     NaN
# http://purl.obolibrary.org/obo/DOID_0050072                     NaN
# http://purl.obolibrary.org/obo/DOID_0050096                     NaN
# http://purl.obolibrary.org/obo/DOID_0050116                     NaN
# http://purl.obolibrary.org/obo/DOID_0050135                     NaN
# http://purl.obolibrary.org/obo/DOID_0050169                     NaN
# http://purl.obolibrary.org/obo/DOID_0050185                     NaN
# http://purl.obolibrary.org/obo/DOID_0050251                     NaN
# http://purl.obolibrary.org/obo/DOID_0050260                     NaN
# http://purl.obolibrary.org/obo/DOID_0050278                     NaN
# http://purl.obolibrary.org/obo/DOID_0050279                     NaN
# http://purl.obolibrary.org/obo/DOID_0050426                     NaN
# http://purl.obolibrary.org/obo/DOID_0050428                     NaN
# http://purl.obolibrary.org/obo/DOID_0050429                     NaN
# http://purl.obolibrary.org/obo/DOID_0050448                     NaN
# http://purl.obolibrary.org/obo/DOID_0050467                     NaN
# http://purl.obolibrary.org/obo/DOID_0050468                     NaN
# http://purl.obolibrary.org/obo/DOID_0050486                     NaN
# http://purl.obolibrary.org/obo/DOID_0050487                     NaN
# http://purl.obolibrary.org/obo/DOID_0050508                     NaN
#
#                                                                       skos:definition{Literal}  \
# http://purl.obolibrary.org/obo/DOID_0040098  An autoimmune disease of skin and connective t...
# http://purl.obolibrary.org/obo/DOID_0050072  A primary systemic mycosis that is a fungal in...
# http://purl.obolibrary.org/obo/DOID_0050096  A dermatophytosis that results_in fungal infec...
# http://purl.obolibrary.org/obo/DOID_0050116  A tinea corporis that results_in fungal infect...
# http://purl.obolibrary.org/obo/DOID_0050135  A fungal infectious disease that results_in in...
# http://purl.obolibrary.org/obo/DOID_0050169  A lupus erythematosus that causes skin lesions...
# http://purl.obolibrary.org/obo/DOID_0050185  A skin disease that is a type of allergic reac...
# http://purl.obolibrary.org/obo/DOID_0050251  A parasitic helminthiasis infectious disease t...
# http://purl.obolibrary.org/obo/DOID_0050260  A parasitic helminthiasis infectious disease t...
# http://purl.obolibrary.org/obo/DOID_0050278  A subcutaneous mycosis that involves a chronic...
# http://purl.obolibrary.org/obo/DOID_0050279  An subcutaneous mycosis that is a chronic infl...
# http://purl.obolibrary.org/obo/DOID_0050426  A skin disease that is characterized by ulcera...
# http://purl.obolibrary.org/obo/DOID_0050428  A palmoplantar keratosis characterized by a we...
# http://purl.obolibrary.org/obo/DOID_0050429  A pemphigus that is characterized by recurring...
# http://purl.obolibrary.org/obo/DOID_0050448  A skin disease characterized by a defect in th...
# http://purl.obolibrary.org/obo/DOID_0050467  A skin disease that is characterized by areas ...
# http://purl.obolibrary.org/obo/DOID_0050468  A syndrome that is characterized by an accumul...
# http://purl.obolibrary.org/obo/DOID_0050486  A skin disease that is characterized by a rash...
# http://purl.obolibrary.org/obo/DOID_0050487  An exanthem that is characterized by a diffuse...
# http://purl.obolibrary.org/obo/DOID_0050508  A smallpox that results_in severe infection, l...
#
#                                                                          skos:inScheme{URIRef}  \
# http://purl.obolibrary.org/obo/DOID_0040098  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050072  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050096  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050116  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050135  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050169  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050185  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050251  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050260  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050278  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050279  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050426  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050428  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050429  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050448  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050467  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050468  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050486  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050487  https://localhost:8443/ontology/Applicanttest/...
# http://purl.obolibrary.org/obo/DOID_0050508  https://localhost:8443/ontology/Applicanttest/...
#
#                                                             skos:prefLabel{Literal}@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                      pemphigus gestationis
# http://purl.obolibrary.org/obo/DOID_0050072                           adiaspiromycosis
# http://purl.obolibrary.org/obo/DOID_0050096                               tinea barbae
# http://purl.obolibrary.org/obo/DOID_0050116                            tinea imbricata
# http://purl.obolibrary.org/obo/DOID_0050135                       subcutaneous mycosis
# http://purl.obolibrary.org/obo/DOID_0050169              cutaneous lupus erythematosus
# http://purl.obolibrary.org/obo/DOID_0050185                        erythema multiforme
# http://purl.obolibrary.org/obo/DOID_0050251                                 coenurosis
# http://purl.obolibrary.org/obo/DOID_0050260                            dioctophymiasis
# http://purl.obolibrary.org/obo/DOID_0050278                         basidiobolomycosis
# http://purl.obolibrary.org/obo/DOID_0050279                         conidiobolomycosis
# http://purl.obolibrary.org/obo/DOID_0050426                   Stevens-Johnson syndrome
# http://purl.obolibrary.org/obo/DOID_0050428  nonepidermolytic palmoplantar keratoderma
# http://purl.obolibrary.org/obo/DOID_0050429                      Hailey-Hailey disease
# http://purl.obolibrary.org/obo/DOID_0050448          hereditary mucosal leukokeratosis
# http://purl.obolibrary.org/obo/DOID_0050467             erythrokeratodermia variabilis
# http://purl.obolibrary.org/obo/DOID_0050468                       yellow nail syndrome
# http://purl.obolibrary.org/obo/DOID_0050486                                   exanthem
# http://purl.obolibrary.org/obo/DOID_0050487                         bacterial exanthem
# http://purl.obolibrary.org/obo/DOID_0050508                              variola major
#
#                                             dcterms:title{Literal}@en  \
# http://purl.obolibrary.org/obo/DOID_0040098                       NaN
# http://purl.obolibrary.org/obo/DOID_0050072                       NaN
# http://purl.obolibrary.org/obo/DOID_0050096                       NaN
# http://purl.obolibrary.org/obo/DOID_0050116                       NaN
# http://purl.obolibrary.org/obo/DOID_0050135                       NaN
# http://purl.obolibrary.org/obo/DOID_0050169                       NaN
# http://purl.obolibrary.org/obo/DOID_0050185                       NaN
# http://purl.obolibrary.org/obo/DOID_0050251                       NaN
# http://purl.obolibrary.org/obo/DOID_0050260                       NaN
# http://purl.obolibrary.org/obo/DOID_0050278                       NaN
# http://purl.obolibrary.org/obo/DOID_0050279                       NaN
# http://purl.obolibrary.org/obo/DOID_0050426                       NaN
# http://purl.obolibrary.org/obo/DOID_0050428                       NaN
# http://purl.obolibrary.org/obo/DOID_0050429                       NaN
# http://purl.obolibrary.org/obo/DOID_0050448                       NaN
# http://purl.obolibrary.org/obo/DOID_0050467                       NaN
# http://purl.obolibrary.org/obo/DOID_0050468                       NaN
# http://purl.obolibrary.org/obo/DOID_0050486                       NaN
# http://purl.obolibrary.org/obo/DOID_0050487                       NaN
# http://purl.obolibrary.org/obo/DOID_0050508                       NaN
#
#                                             skos:hasTopConcept{URIRef}  \
# http://purl.obolibrary.org/obo/DOID_0040098                        NaN
# http://purl.obolibrary.org/obo/DOID_0050072                        NaN
# http://purl.obolibrary.org/obo/DOID_0050096                        NaN
# http://purl.obolibrary.org/obo/DOID_0050116                        NaN
# http://purl.obolibrary.org/obo/DOID_0050135                        NaN
# http://purl.obolibrary.org/obo/DOID_0050169                        NaN
# http://purl.obolibrary.org/obo/DOID_0050185                        NaN
# http://purl.obolibrary.org/obo/DOID_0050251                        NaN
# http://purl.obolibrary.org/obo/DOID_0050260                        NaN
# http://purl.obolibrary.org/obo/DOID_0050278                        NaN
# http://purl.obolibrary.org/obo/DOID_0050279                        NaN
# http://purl.obolibrary.org/obo/DOID_0050426                        NaN
# http://purl.obolibrary.org/obo/DOID_0050428                        NaN
# http://purl.obolibrary.org/obo/DOID_0050429                        NaN
# http://purl.obolibrary.org/obo/DOID_0050448                        NaN
# http://purl.obolibrary.org/obo/DOID_0050467                        NaN
# http://purl.obolibrary.org/obo/DOID_0050468                        NaN
# http://purl.obolibrary.org/obo/DOID_0050486                        NaN
# http://purl.obolibrary.org/obo/DOID_0050487                        NaN
# http://purl.obolibrary.org/obo/DOID_0050508                        NaN
#
#                                             skos:topConceptOf{URIRef}
# http://purl.obolibrary.org/obo/DOID_0040098                       NaN
# http://purl.obolibrary.org/obo/DOID_0050072                       NaN
# http://purl.obolibrary.org/obo/DOID_0050096                       NaN
# http://purl.obolibrary.org/obo/DOID_0050116                       NaN
# http://purl.obolibrary.org/obo/DOID_0050135                       NaN
# http://purl.obolibrary.org/obo/DOID_0050169                       NaN
# http://purl.obolibrary.org/obo/DOID_0050185                       NaN
# http://purl.obolibrary.org/obo/DOID_0050251                       NaN
# http://purl.obolibrary.org/obo/DOID_0050260                       NaN
# http://purl.obolibrary.org/obo/DOID_0050278                       NaN
# http://purl.obolibrary.org/obo/DOID_0050279                       NaN
# http://purl.obolibrary.org/obo/DOID_0050426                       NaN
# http://purl.obolibrary.org/obo/DOID_0050428                       NaN
# http://purl.obolibrary.org/obo/DOID_0050429                       NaN
# http://purl.obolibrary.org/obo/DOID_0050448                       NaN
# http://purl.obolibrary.org/obo/DOID_0050467                       NaN
# http://purl.obolibrary.org/obo/DOID_0050468                       NaN
# http://purl.obolibrary.org/obo/DOID_0050486                       NaN
# http://purl.obolibrary.org/obo/DOID_0050487                       NaN
# http://purl.obolibrary.org/obo/DOID_0050508                       NaN
#
# [20 rows x 21 columns]

# %% [markdown]
# ## Step 3: Extract IDs and Preferred Labels
#
# Now we need to extract IDs and preferred labels from our file, with the caveat that the concepts _must_ be within the "skin cancer" branch. From a quick query of OBO, we see this ID is [`http://purl.obolibrary.org/obo/DOID_4159`](http://www.ontobee.org/ontology/DOID?iri=http://purl.obolibrary.org/obo/DOID_4159). Thus, we only want concepts whose parent (in this case, the predicate is `skos:broader`) is DOID:4159. We can use SPARQL to filter the data.

# %%
results = g.query("""
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    SELECT ?concept ?label
    WHERE {
    
    # ?concept skos:prefLabel ?label .
    # ?concept skos:broader* <http://purl.obolibrary.org/obo/DOID_4159> .
    }
""")

print('Results!')
print(type(results))
for row in results:
    print(row)
# Out:
# Results!
# <class 'rdflib.plugins.sparql.processor.SPARQLResult'>
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4159'), rdflib.term.Literal('skin cancer', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13168'), rdflib.term.Literal('prepuce cancer', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8923'), rdflib.term.Literal('skin melanoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_6367'), rdflib.term.Literal('acral lentiginous melanoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10047'), rdflib.term.Literal('nodular malignant melanoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10054'), rdflib.term.Literal('skin amelanotic melanoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10044'), rdflib.term.Literal('balloon cell malignant melanoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10040'), rdflib.term.Literal('malignant eyelid melanoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3451'), rdflib.term.Literal('skin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4871'), rdflib.term.Literal('cutaneous adenocystic carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3450'), rdflib.term.Literal("cutaneous Paget's disease", lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_6425'), rdflib.term.Literal('eyelid carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3965'), rdflib.term.Literal('Merkel cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2513'), rdflib.term.Literal('basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4300'), rdflib.term.Literal('superficial basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4304'), rdflib.term.Literal('signet ring basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4303'), rdflib.term.Literal('sarcomatoid basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4302'), rdflib.term.Literal('cystic basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4301'), rdflib.term.Literal('vulva basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4283'), rdflib.term.Literal('anal margin basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4295'), rdflib.term.Literal('follicular basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4282'), rdflib.term.Literal('pigmented basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4294'), rdflib.term.Literal('adenoid basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4281'), rdflib.term.Literal('metatypical basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4293'), rdflib.term.Literal('clear cell basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4280'), rdflib.term.Literal('nodular basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4292'), rdflib.term.Literal('morpheaform basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4291'), rdflib.term.Literal('fibroepithelial basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4290'), rdflib.term.Literal('adamantinoid basal cell epithelioma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4279'), rdflib.term.Literal('infundibulocystic basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4278'), rdflib.term.Literal('scrotum basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5063'), rdflib.term.Literal('basosquamous carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4289'), rdflib.term.Literal('micronodular basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4287'), rdflib.term.Literal('external ear basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4299'), rdflib.term.Literal('infiltrative basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4286'), rdflib.term.Literal('sebaceous basal cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5376'), rdflib.term.Literal('skin pilomatrix carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3151'), rdflib.term.Literal('skin squamous cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3149'), rdflib.term.Literal('keratoacanthoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5585'), rdflib.term.Literal('Ferguson-Smith tumor', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5536'), rdflib.term.Literal('sarcomatoid squamous cell skin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8288'), rdflib.term.Literal('clear cell squamous cell skin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8122'), rdflib.term.Literal('pseudovascular skin squamous cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3751'), rdflib.term.Literal('plantar verrucous skin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7643'), rdflib.term.Literal('acantholytic squamous cell skin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7039'), rdflib.term.Literal('Borst-Jadassohn intraepidermal carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_6944'), rdflib.term.Literal('vulvar seborrheic keratosis', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_6943'), rdflib.term.Literal('vulvar inverted follicular keratosis', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4840'), rdflib.term.Literal('sebaceous carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4839'), rdflib.term.Literal('sebaceous adenocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2687'), rdflib.term.Literal('skin sarcoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5712'), rdflib.term.Literal('cutaneous liposarcoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4517'), rdflib.term.Literal('skin angiosarcoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5273'), rdflib.term.Literal('cutaneous leiomyosarcoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2430'), rdflib.term.Literal('skin glomus tumor', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1243'), rdflib.term.Literal('labia minora cancer', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1293'), rdflib.term.Literal('labia minora carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7049'), rdflib.term.Literal('basaloid squamous cell skin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5042'), rdflib.term.Literal('malignant granular cell myoblastoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13691'), rdflib.term.Literal('dermoid cyst of skin', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5274'), rdflib.term.Literal('malignant dermis tumor', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1906'), rdflib.term.Literal('malignant skin fibrous histiocytoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7639'), rdflib.term.Literal('malignant granular cell skin tumor', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2095'), rdflib.term.Literal('sweat gland cancer', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5667'), rdflib.term.Literal('sweat gland carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5590'), rdflib.term.Literal('aggressive digital papillary adenocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5570'), rdflib.term.Literal('malignant acrospiroma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4921'), rdflib.term.Literal('eccrine sweat gland cancer', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7960'), rdflib.term.Literal('malignant spiradenoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5569'), rdflib.term.Literal('malignant syringoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7566'), rdflib.term.Literal('eccrine porocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4920'), rdflib.term.Literal('eccrine adenocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5591'), rdflib.term.Literal('eccrine papillary adenocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4934'), rdflib.term.Literal('apocrine sweat gland cancer', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4933'), rdflib.term.Literal('apocrine adenocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_6446'), rdflib.term.Literal('ceruminous adenocarcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4284'), rdflib.term.Literal('anal margin carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7708'), rdflib.term.Literal("perianal skin Paget's disease", lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12239'), rdflib.term.Literal('anal margin squamous cell carcinoma', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13389'), rdflib.term.Literal('labia majora carcinoma', lang='en'))

# %% [markdown]
# ### Step 3: Results
# Our results look accurate (we can double check by browsing the "Skin cancer" hierarchy on OBO to make sure we got all the grandchildren).
#
# However, you'll notice the objects returned are a special type, "SPARQLResult." We'll need to get this back into Python data types and into another DataFrame. We can look to GitHub, specifically the [SPARQLWrapper repo issues](https://github.com/RDFLib/sparqlwrapper/issues/125) for some function ideas. Here's one solution:

# %%
from pandas import DataFrame
from rdflib.plugins.sparql.processor import SPARQLResult

def sparql_results_to_df(results: SPARQLResult) -> DataFrame:
    """
    Export results from an rdflib SPARQL query into a `pandas.DataFrame`,
    using Python types. See https://github.com/RDFLib/rdflib/issues/1179.
    """
    return DataFrame(
        data=([None if x is None else x.toPython() for x in row] for row in results),
        columns=[str(x) for x in results.vars],
    )

df1 = sparql_results_to_df(results)

# %%
df1
# Out:
#                                       concept  \
# 0    http://purl.obolibrary.org/obo/DOID_4159
# 1   http://purl.obolibrary.org/obo/DOID_13168
# 2    http://purl.obolibrary.org/obo/DOID_8923
# 3    http://purl.obolibrary.org/obo/DOID_6367
# 4   http://purl.obolibrary.org/obo/DOID_10047
# ..                                        ...
# 75   http://purl.obolibrary.org/obo/DOID_6446
# 76   http://purl.obolibrary.org/obo/DOID_4284
# 77   http://purl.obolibrary.org/obo/DOID_7708
# 78  http://purl.obolibrary.org/obo/DOID_12239
# 79  http://purl.obolibrary.org/obo/DOID_13389
#
#                                   label
# 0                           skin cancer
# 1                        prepuce cancer
# 2                         skin melanoma
# 3            acral lentiginous melanoma
# 4            nodular malignant melanoma
# ..                                  ...
# 75            ceruminous adenocarcinoma
# 76                anal margin carcinoma
# 77        perianal skin Paget's disease
# 78  anal margin squamous cell carcinoma
# 79               labia majora carcinoma
#
# [80 rows x 2 columns]

# %% [markdown]
# This is much more readable. However, we have Concept URIs, where we'd prefer to have DOIDs we can pass to the API. So let's do so regex on the values:

# %%
df1['concept'] = df1['concept'].str.replace(r'_', ':', regex=True)
df1['concept'] = df1['concept'].str.replace(r'^http://purl.obolibrary.org/obo/', '', regex=True)
df1['MONDO_IRI'] = ''
df1
# Out:
#        concept                                label MONDO_IRI
# 0    DOID:4159                          skin cancer
# 1   DOID:13168                       prepuce cancer
# 2    DOID:8923                        skin melanoma
# 3    DOID:6367           acral lentiginous melanoma
# 4   DOID:10047           nodular malignant melanoma
# ..         ...                                  ...       ...
# 75   DOID:6446            ceruminous adenocarcinoma
# 76   DOID:4284                anal margin carcinoma
# 77   DOID:7708        perianal skin Paget's disease
# 78  DOID:12239  anal margin squamous cell carcinoma
# 79  DOID:13389               labia majora carcinoma
#
# [80 rows x 3 columns]

# %% [markdown]
# # Step 4: Retrieve Mappings to Other Ontologies
#
# Now that we have our IDs and preferred labels, we need to get mappings to other ontologies.
#
# For our Preferred Labels, we will get mappings to MeSH and EFO via the [EBI OLS API](https://www.ebi.ac.uk/ols/docs/api). But looking into it, we can first query all ontologies to see what we have access to. We can see that MeSH is not available. When we use OXO, we see why this is perhaps the case: it is considered a type "Database" and not "Ontology." Therefore, if our calls to OLS try to specify MeSH as an ontology, it won't return anything.
#
# A compromise we can make in this case is using MONDO. This might be desirable because:
# * From testing some API calls, the MONDO results have very high scoring (about as high as EFO hits)
# * [MONDO data sources](https://mondo.monarchinitiative.org/pages/sources/) seem encouraging, and have MeSH as a data source
#
# For our IDs, we will get mappings to MeSH and EFO via the [EBI OXO API](https://www.ebi.ac.uk/spot/oxo/docs/api). After trying some sample queries, they can be a bit messy, so we will have to parse that JSON carefully to get the right hits.

# %% [markdown]
# ## First up: OLS Exploration
#
# We want to explore the API a bit and see what kind of responses we get. Let's use `requests` to make a sample call for the term "anal margin carcinoma." while specifying MONDO

# %%
url = "http://www.ebi.ac.uk/ols/api/select?q=anal%20margin%20carcinoma&queryFields=label&ontology=mondo&fieldList=id,iri,label,score,synonym"
response = requests.get(url).json()

# %%
response['response']
# Out:
# {'numFound': 3,
#  'start': 0,
#  'maxScore': 10.319454,
#  'docs': [{'id': 'mondo:class:http://purl.obolibrary.org/obo/MONDO_0002941',
#    'iri': 'http://purl.obolibrary.org/obo/MONDO_0002941',
#    'label': 'anal margin carcinoma',
#    'score': 10.319454},
#   {'id': 'mondo:class:http://purl.obolibrary.org/obo/MONDO_0002940',
#    'iri': 'http://purl.obolibrary.org/obo/MONDO_0002940',
#    'label': 'anal margin basal cell carcinoma',
#    'score': 0.010781731},
#   {'id': 'mondo:class:http://purl.obolibrary.org/obo/MONDO_0001470',
#    'iri': 'http://purl.obolibrary.org/obo/MONDO_0001470',
#    'label': 'anal margin squamous cell carcinoma',
#    'score': 0.010781731}]}

# %%
response['response']['docs'][0]['iri']
# Out:
# 'http://purl.obolibrary.org/obo/MONDO_0002941'

# %%
labels = df1['label']
print(labels)
# Out:
# 0                             skin cancer
# 1                          prepuce cancer
# 2                           skin melanoma
# 3              acral lentiginous melanoma
# 4              nodular malignant melanoma
#                      ...
# 75              ceruminous adenocarcinoma
# 76                  anal margin carcinoma
# 77          perianal skin Paget's disease
# 78    anal margin squamous cell carcinoma
# 79                 labia majora carcinoma
# Name: label, Length: 80, dtype: object

# %%
iris = []
for label in labels:
    encodedLabel = urllib.parse.quote(label)
    url = "http://www.ebi.ac.uk/ols/api/select?q="+encodedLabel+"&queryFields=label&ontology=mondo&fieldList=id,iri,label,score,synonym"
    response = requests.get(url).json()
    if response['response']['numFound'] == 1:
        iri_hit = [i['iri'] for i in response["response"]["docs"]]
        iri_hit = str(iri_hit)[2:-2]
        iris.append(iri_hit.replace("http://purl.obolibrary.org/obo/", ""))
    elif response['response']['numFound'] > 1:
        iri_hits = [i['iri'] for i in response["response"]["docs"]]
        iri_hit = iri_hits[0]
        iris.append(iri_hit.replace("http://purl.obolibrary.org/obo/", ""))
    else:
        iri_hit = "No result"
        iris.append(iri_hit)
df1['MONDO_IRI'] = iris

# %%
df1
# Out:
#        concept                                label      MONDO_IRI
# 0    DOID:4159                          skin cancer  MONDO_0002898
# 1   DOID:13168                       prepuce cancer  MONDO_0001653
# 2    DOID:8923                        skin melanoma  MONDO_0005208
# 3    DOID:6367           acral lentiginous melanoma  MONDO_0003865
# 4   DOID:10047           nodular malignant melanoma  MONDO_0000930
# ..         ...                                  ...            ...
# 75   DOID:6446            ceruminous adenocarcinoma      No result
# 76   DOID:4284                anal margin carcinoma  MONDO_0002941
# 77   DOID:7708        perianal skin Paget's disease      No result
# 78  DOID:12239  anal margin squamous cell carcinoma  MONDO_0001470
# 79  DOID:13389               labia majora carcinoma  MONDO_0001702
#
# [80 rows x 3 columns]

# %%
iris = []
for label in labels:
    encodedLabel = urllib.parse.quote(label)
    url = "http://www.ebi.ac.uk/ols/api/select?q="+encodedLabel+"&queryFields=label&ontology=efo&fieldList=id,iri,label,score,synonym"
    response = requests.get(url).json()
    if response['response']['numFound'] == 1:
        iri_hit = [i['iri'] for i in response["response"]["docs"]]
        iri_hit = str(iri_hit)[2:-2]
        iris.append(iri_hit.replace("http://www.ebi.ac.uk/efo/", ""))
    elif response['response']['numFound'] > 1:
        iri_hits = [i['iri'] for i in response["response"]["docs"]]
        iri_hit = iri_hits[0]
        iris.append(iri_hit.replace("http://www.ebi.ac.uk/efo/", ""))
    else:
        iri_hit = "No result"
        iris.append(iri_hit)
df1['EFO_IRI'] = iris

# %%
df1
# Out:
#        concept                                label      MONDO_IRI  \
# 0    DOID:4159                          skin cancer  MONDO_0002898
# 1   DOID:13168                       prepuce cancer  MONDO_0001653
# 2    DOID:8923                        skin melanoma  MONDO_0005208
# 3    DOID:6367           acral lentiginous melanoma  MONDO_0003865
# 4   DOID:10047           nodular malignant melanoma  MONDO_0000930
# ..         ...                                  ...            ...
# 75   DOID:6446            ceruminous adenocarcinoma      No result
# 76   DOID:4284                anal margin carcinoma  MONDO_0002941
# 77   DOID:7708        perianal skin Paget's disease      No result
# 78  DOID:12239  anal margin squamous cell carcinoma  MONDO_0001470
# 79  DOID:13389               labia majora carcinoma  MONDO_0001702
#
#                                          EFO_IRI
# 0   http://purl.obolibrary.org/obo/MONDO_0002898
# 1                                      No result
# 2                                    EFO_0000389
# 3   http://purl.obolibrary.org/obo/MONDO_0003865
# 4                                    EFO_0008515
# ..                                           ...
# 75                                     No result
# 76                                     No result
# 77                                     No result
# 78                                     No result
# 79                                     No result
#
# [80 rows x 4 columns]

# %%
df1['EFO_IRI'] = df1.EFO_IRI.str.replace(r'^http://purl.obolibrary.org/obo/.+', r'No result', regex=True)

# %%
df1
# Out:
#        concept                                label      MONDO_IRI  \
# 0    DOID:4159                          skin cancer  MONDO_0002898
# 1   DOID:13168                       prepuce cancer  MONDO_0001653
# 2    DOID:8923                        skin melanoma  MONDO_0005208
# 3    DOID:6367           acral lentiginous melanoma  MONDO_0003865
# 4   DOID:10047           nodular malignant melanoma  MONDO_0000930
# ..         ...                                  ...            ...
# 75   DOID:6446            ceruminous adenocarcinoma      No result
# 76   DOID:4284                anal margin carcinoma  MONDO_0002941
# 77   DOID:7708        perianal skin Paget's disease      No result
# 78  DOID:12239  anal margin squamous cell carcinoma  MONDO_0001470
# 79  DOID:13389               labia majora carcinoma  MONDO_0001702
#
#         EFO_IRI
# 0     No result
# 1     No result
# 2   EFO_0000389
# 3     No result
# 4   EFO_0008515
# ..          ...
# 75    No result
# 76    No result
# 77    No result
# 78    No result
# 79    No result
#
# [80 rows x 4 columns]

# %%
df1["OLS_Mappings"] = df1[['MONDO_IRI', 'EFO_IRI']].agg('; '.join, axis=1)
df1['OLS_Mappings'] = df1['OLS_Mappings'].str.replace('No result; ', '')
df1['OLS_Mappings'] = df1['OLS_Mappings'].str.replace('; No result', '')

# %%
df1
# Out:
#        concept                                label      MONDO_IRI  \
# 0    DOID:4159                          skin cancer  MONDO_0002898
# 1   DOID:13168                       prepuce cancer  MONDO_0001653
# 2    DOID:8923                        skin melanoma  MONDO_0005208
# 3    DOID:6367           acral lentiginous melanoma  MONDO_0003865
# 4   DOID:10047           nodular malignant melanoma  MONDO_0000930
# ..         ...                                  ...            ...
# 75   DOID:6446            ceruminous adenocarcinoma      No result
# 76   DOID:4284                anal margin carcinoma  MONDO_0002941
# 77   DOID:7708        perianal skin Paget's disease      No result
# 78  DOID:12239  anal margin squamous cell carcinoma  MONDO_0001470
# 79  DOID:13389               labia majora carcinoma  MONDO_0001702
#
#         EFO_IRI                OLS_Mappings
# 0     No result               MONDO_0002898
# 1     No result               MONDO_0001653
# 2   EFO_0000389  MONDO_0005208; EFO_0000389
# 3     No result               MONDO_0003865
# 4   EFO_0008515  MONDO_0000930; EFO_0008515
# ..          ...                         ...
# 75    No result                   No result
# 76    No result               MONDO_0002941
# 77    No result                   No result
# 78    No result               MONDO_0001470
# 79    No result               MONDO_0001702
#
# [80 rows x 5 columns]

# %% [markdown]
# ## Next: OXO Exploration
#
# Now we'd like to query the OXO service using our list of IDs. Our targets are MeSH and EFO. So let's dive in.

# %%
# Sample call for 'skin melanoma'
url = "https://www.ebi.ac.uk/spot/oxo/api/mappings?fromId=DOID:8923"
response = requests.get(url).json()

# %%
# To find MeSH terms
for r in response['_embedded']['mappings']:
    if r['toTerm']['datasource']['prefix'] == 'MeSH':
        print(r['toTerm']['uri'])
# Out:
# http://identifiers.org/MeSH:C562393
# http://identifiers.org/MeSH:C562393

# %%
# To find EFO terms
for r in response['_embedded']['mappings']:
    if r['fromTerm']['datasource']['prefix'] == 'EFO':
        print(r['fromTerm']['uri'])
# Out:
# http://www.ebi.ac.uk/efo/EFO_0000389

# %%
ids = df1['concept']
print(ids[0:20])
# Out:
# 0      DOID:4159
# 1     DOID:13168
# 2      DOID:8923
# 3      DOID:6367
# 4     DOID:10047
# 5     DOID:10054
# 6     DOID:10044
# 7     DOID:10040
# 8      DOID:3451
# 9      DOID:4871
# 10     DOID:3450
# 11     DOID:6425
# 12     DOID:3965
# 13     DOID:2513
# 14     DOID:4300
# 15     DOID:4304
# 16     DOID:4303
# 17     DOID:4302
# 18     DOID:4301
# 19     DOID:4283
# Name: concept, dtype: object

# %%
meshes = []
efos = []
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

for i in ids:
    url = "https://www.ebi.ac.uk/spot/oxo/api/mappings?fromId="+i
    response = session.get(url).json()
    try:
        mesh_hits = [i['toTerm']['curie'] for i in response['_embedded']['mappings'] if i['toTerm']['datasource']['prefix'] == 'MeSH']
        efo_hits = [i['fromTerm']['curie'] for i in response['_embedded']['mappings'] if i['fromTerm']['datasource']['prefix'] == 'EFO']
        efo_hits = str(efo_hits)[2:-2]
        meshes.append(mesh_hits[0])
        efos.append(efo_hits)
    except:
        meshes.append('No result')
        efos.append('No result')

# %%
df1['MESH_ID'] = meshes
df1['EFO_ID'] = efos

# %%
df1
# Out:
#        concept                                label      MONDO_IRI  \
# 0    DOID:4159                          skin cancer  MONDO_0002898
# 1   DOID:13168                       prepuce cancer  MONDO_0001653
# 2    DOID:8923                        skin melanoma  MONDO_0005208
# 3    DOID:6367           acral lentiginous melanoma  MONDO_0003865
# 4   DOID:10047           nodular malignant melanoma  MONDO_0000930
# ..         ...                                  ...            ...
# 75   DOID:6446            ceruminous adenocarcinoma      No result
# 76   DOID:4284                anal margin carcinoma  MONDO_0002941
# 77   DOID:7708        perianal skin Paget's disease      No result
# 78  DOID:12239  anal margin squamous cell carcinoma  MONDO_0001470
# 79  DOID:13389               labia majora carcinoma  MONDO_0001702
#
#         EFO_IRI                OLS_Mappings       MESH_ID       EFO_ID
# 0     No result               MONDO_0002898  MeSH:D012878  EFO:0004198
# 1     No result               MONDO_0001653     No result    No result
# 2   EFO_0000389  MONDO_0005208; EFO_0000389  MeSH:C562393  EFO:0000389
# 3     No result               MONDO_0003865     No result    No result
# 4   EFO_0008515  MONDO_0000930; EFO_0008515     No result    No result
# ..          ...                         ...           ...          ...
# 75    No result                   No result     No result    No result
# 76    No result               MONDO_0002941     No result    No result
# 77    No result                   No result     No result    No result
# 78    No result               MONDO_0001470     No result    No result
# 79    No result               MONDO_0001702     No result    No result
#
# [80 rows x 7 columns]

# %%
df1["OXO_Mappings"] = df1[['MESH_ID', 'EFO_ID']].agg('; '.join, axis=1)
df1['OXO_Mappings'] = df1['OXO_Mappings'].str.replace('No result; ', '')
df1['OXO_Mappings'] = df1['OXO_Mappings'].str.replace('; No result', '')

# %%
df1
# Out:
#        concept                                label      MONDO_IRI  \
# 0    DOID:4159                          skin cancer  MONDO_0002898
# 1   DOID:13168                       prepuce cancer  MONDO_0001653
# 2    DOID:8923                        skin melanoma  MONDO_0005208
# 3    DOID:6367           acral lentiginous melanoma  MONDO_0003865
# 4   DOID:10047           nodular malignant melanoma  MONDO_0000930
# ..         ...                                  ...            ...
# 75   DOID:6446            ceruminous adenocarcinoma      No result
# 76   DOID:4284                anal margin carcinoma  MONDO_0002941
# 77   DOID:7708        perianal skin Paget's disease      No result
# 78  DOID:12239  anal margin squamous cell carcinoma  MONDO_0001470
# 79  DOID:13389               labia majora carcinoma  MONDO_0001702
#
#         EFO_IRI                OLS_Mappings       MESH_ID       EFO_ID  \
# 0     No result               MONDO_0002898  MeSH:D012878  EFO:0004198
# 1     No result               MONDO_0001653     No result    No result
# 2   EFO_0000389  MONDO_0005208; EFO_0000389  MeSH:C562393  EFO:0000389
# 3     No result               MONDO_0003865     No result    No result
# 4   EFO_0008515  MONDO_0000930; EFO_0008515     No result    No result
# ..          ...                         ...           ...          ...
# 75    No result                   No result     No result    No result
# 76    No result               MONDO_0002941     No result    No result
# 77    No result                   No result     No result    No result
# 78    No result               MONDO_0001470     No result    No result
# 79    No result               MONDO_0001702     No result    No result
#
#                  OXO_Mappings
# 0   MeSH:D012878; EFO:0004198
# 1                   No result
# 2   MeSH:C562393; EFO:0000389
# 3                   No result
# 4                   No result
# ..                        ...
# 75                  No result
# 76                  No result
# 77                  No result
# 78                  No result
# 79                  No result
#
# [80 rows x 8 columns]

# %% [markdown]
# # Step 5: Write Results to a Delimited File
#
# Now we have our DataFrame complete with mappings, so now we just need to write out the file to CSV.

# %%
df_final = df1[['concept', 'label', 'OLS_Mappings', 'OXO_Mappings']]
df_final
# Out:
#        concept                                label  \
# 0    DOID:4159                          skin cancer
# 1   DOID:13168                       prepuce cancer
# 2    DOID:8923                        skin melanoma
# 3    DOID:6367           acral lentiginous melanoma
# 4   DOID:10047           nodular malignant melanoma
# ..         ...                                  ...
# 75   DOID:6446            ceruminous adenocarcinoma
# 76   DOID:4284                anal margin carcinoma
# 77   DOID:7708        perianal skin Paget's disease
# 78  DOID:12239  anal margin squamous cell carcinoma
# 79  DOID:13389               labia majora carcinoma
#
#                   OLS_Mappings               OXO_Mappings
# 0                MONDO_0002898  MeSH:D012878; EFO:0004198
# 1                MONDO_0001653                  No result
# 2   MONDO_0005208; EFO_0000389  MeSH:C562393; EFO:0000389
# 3                MONDO_0003865                  No result
# 4   MONDO_0000930; EFO_0008515                  No result
# ..                         ...                        ...
# 75                   No result                  No result
# 76               MONDO_0002941                  No result
# 77                   No result                  No result
# 78               MONDO_0001470                  No result
# 79               MONDO_0001702                  No result
#
# [80 rows x 4 columns]

# %%
# Un-comment to actually make the file
# df_final.to_csv('../output/output.csv')
